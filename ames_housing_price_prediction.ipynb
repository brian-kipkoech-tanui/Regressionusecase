# %% [markdown]
# # End to End ML Project: Housing SalePrice Prediction

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load the dataset

# %%
dataset = pd.read_csv("./ames_unprocessed_data.csv")
# Check the basic info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MSSubClass    1460 non-null   int64
#  1   MSZoning      1460 non-null   object
#  2   LotFrontage   1201 non-null   float64
#  3   LotArea       1460 non-null   int64
#  4   Neighborhood  1460 non-null   object
#  5   BldgType      1460 non-null   object
#  6   HouseStyle    1460 non-null   object
#  7   OverallQual   1460 non-null   int64
#  8   OverallCond   1460 non-null   int64
#  9   YearBuilt     1460 non-null   int64
#  10  Remodeled     1460 non-null   int64
#  11  GrLivArea     1460 non-null   int64
#  12  BsmtFullBath  1460 non-null   int64
#  13  BsmtHalfBath  1460 non-null   int64
#  14  FullBath      1460 non-null   int64
#  15  HalfBath      1460 non-null   int64
#  16  BedroomAbvGr  1460 non-null   int64
#  17  Fireplaces    1460 non-null   int64
#  18  GarageArea    1460 non-null   int64
#  19  PavedDrive    1460 non-null   object
#  20  SalePrice     1460 non-null   int64
# dtypes: float64(1), int64(15), object(5)
# memory usage: 239.7+ KB

# %% [markdown]
# ## Handle missing values

# %%
# Check the column with missing values
data = dataset.copy()
dataset.isna().sum()
# Out:
# MSSubClass        0
# MSZoning          0
# LotFrontage     259
# LotArea           0
# Neighborhood      0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# Remodeled         0
# GrLivArea         0
# BsmtFullBath      0
# BsmtHalfBath      0
# FullBath          0
# HalfBath          0
# BedroomAbvGr      0
# Fireplaces        0
# GarageArea        0
# PavedDrive        0
# SalePrice         0
# dtype: int64

# %%
# Use the sklearn's SimpleImputer() class to handle all missing values
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
# fit the imputer on numerical columns
int_cols = dataset.select_dtypes(include=['float', 'int']).columns.to_list()
imputer.fit(dataset[int_cols])
dataset[int_cols] = imputer.transform(dataset[int_cols])
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MSSubClass    1460 non-null   float64
#  1   MSZoning      1460 non-null   object
#  2   LotFrontage   1460 non-null   float64
#  3   LotArea       1460 non-null   float64
#  4   Neighborhood  1460 non-null   object
#  5   BldgType      1460 non-null   object
#  6   HouseStyle    1460 non-null   object
#  7   OverallQual   1460 non-null   float64
#  8   OverallCond   1460 non-null   float64
#  9   YearBuilt     1460 non-null   float64
#  10  Remodeled     1460 non-null   float64
#  11  GrLivArea     1460 non-null   float64
#  12  BsmtFullBath  1460 non-null   float64
#  13  BsmtHalfBath  1460 non-null   float64
#  14  FullBath      1460 non-null   float64
#  15  HalfBath      1460 non-null   float64
#  16  BedroomAbvGr  1460 non-null   float64
#  17  Fireplaces    1460 non-null   float64
#  18  GarageArea    1460 non-null   float64
#  19  PavedDrive    1460 non-null   object
#  20  SalePrice     1460 non-null   float64
# dtypes: float64(16), object(5)
# memory usage: 239.7+ KB

# %% [markdown]
# ## Checking the distribution of continuous variable

# %%
import seaborn as sns
sns.set()
dataset[int_cols].hist(figsize=(20,8))
plt.show()

# %% [markdown]
# ## Feature Scaling

# %%
dataset
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Neighborhood BldgType  \
# 0           60.0       RL         65.0   8450.0      CollgCr     1Fam
# 1           20.0       RL         80.0   9600.0      Veenker     1Fam
# 2           60.0       RL         68.0  11250.0      CollgCr     1Fam
# 3           70.0       RL         60.0   9550.0      Crawfor     1Fam
# 4           60.0       RL         84.0  14260.0      NoRidge     1Fam
# ...          ...      ...          ...      ...          ...      ...
# 1455        60.0       RL         62.0   7917.0      Gilbert     1Fam
# 1456        20.0       RL         85.0  13175.0       NWAmes     1Fam
# 1457        70.0       RL         66.0   9042.0      Crawfor     1Fam
# 1458        20.0       RL         68.0   9717.0        NAmes     1Fam
# 1459        20.0       RL         75.0   9937.0      Edwards     1Fam
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  ...  GrLivArea  \
# 0        2Story          7.0          5.0     2003.0  ...     1710.0
# 1        1Story          6.0          8.0     1976.0  ...     1262.0
# 2        2Story          7.0          5.0     2001.0  ...     1786.0
# 3        2Story          7.0          5.0     1915.0  ...     1717.0
# 4        2Story          8.0          5.0     2000.0  ...     2198.0
# ...         ...          ...          ...        ...  ...        ...
# 1455     2Story          6.0          5.0     1999.0  ...     1647.0
# 1456     1Story          6.0          6.0     1978.0  ...     2073.0
# 1457     2Story          7.0          9.0     1941.0  ...     2340.0
# 1458     1Story          5.0          6.0     1950.0  ...     1078.0
# 1459     1Story          5.0          6.0     1965.0  ...     1256.0
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0              1.0           0.0       2.0       1.0           3.0
# 1              0.0           1.0       2.0       0.0           3.0
# 2              1.0           0.0       2.0       1.0           3.0
# 3              1.0           0.0       1.0       0.0           3.0
# 4              1.0           0.0       2.0       1.0           4.0
# ...            ...           ...       ...       ...           ...
# 1455           0.0           0.0       2.0       1.0           3.0
# 1456           1.0           0.0       2.0       0.0           3.0
# 1457           0.0           0.0       2.0       0.0           4.0
# 1458           1.0           0.0       1.0       0.0           2.0
# 1459           1.0           0.0       1.0       1.0           3.0
#
#       Fireplaces  GarageArea  PavedDrive SalePrice
# 0            0.0       548.0           Y  208500.0
# 1            1.0       460.0           Y  181500.0
# 2            1.0       608.0           Y  223500.0
# 3            1.0       642.0           Y  140000.0
# 4            1.0       836.0           Y  250000.0
# ...          ...         ...         ...       ...
# 1455         1.0       460.0           Y  175000.0
# 1456         2.0       500.0           Y  210000.0
# 1457         2.0       252.0           Y  266500.0
# 1458         0.0       240.0           Y  142125.0
# 1459         0.0       276.0           Y  147500.0
#
# [1460 rows x 21 columns]

# %%
# Create the features and label
X = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1].values
y = y.reshape(len(y), 1)

# %%
sc_x = StandardScaler()
sc_y = StandardScaler()
# Standardise the numerical columns
X[int_cols[:-1]] = sc_x.fit_transform(X[int_cols[:-1]])
y = sc_y.fit_transform(y)
X
# Out:
#       MSSubClass MSZoning  LotFrontage   LotArea Neighborhood BldgType  \
# 0       0.073375       RL    -0.229372 -0.207142      CollgCr     1Fam
# 1      -0.872563       RL     0.451936 -0.091886      Veenker     1Fam
# 2       0.073375       RL    -0.093110  0.073480      CollgCr     1Fam
# 3       0.309859       RL    -0.456474 -0.096897      Crawfor     1Fam
# 4       0.073375       RL     0.633618  0.375148      NoRidge     1Fam
# ...          ...      ...          ...       ...          ...      ...
# 1455    0.073375       RL    -0.365633 -0.260560      Gilbert     1Fam
# 1456   -0.872563       RL     0.679039  0.266407       NWAmes     1Fam
# 1457    0.309859       RL    -0.183951 -0.147810      Crawfor     1Fam
# 1458   -0.872563       RL    -0.093110 -0.080160        NAmes     1Fam
# 1459   -0.872563       RL     0.224833 -0.058112      Edwards     1Fam
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  Remodeled  GrLivArea  \
# 0        2Story     0.651479    -0.517200   1.050994  -0.954460   0.370333
# 1        1Story    -0.071836     2.179628   0.156734  -0.954460  -0.482512
# 2        2Story     0.651479    -0.517200   0.984752   1.047712   0.515013
# 3        2Story     0.651479    -0.517200  -1.863632   1.047712   0.383659
# 4        2Story     1.374795    -0.517200   0.951632  -0.954460   1.299326
# ...         ...          ...          ...        ...        ...        ...
# 1455     2Story    -0.071836    -0.517200   0.918511   1.047712   0.250402
# 1456     1Story    -0.071836     0.381743   0.222975   1.047712   1.061367
# 1457     2Story     0.651479     3.078570  -1.002492   1.047712   1.569647
# 1458     1Story    -0.795151     0.381743  -0.704406   1.047712  -0.832788
# 1459     1Story    -0.795151     0.381743  -0.207594  -0.954460  -0.493934
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0         1.107810     -0.241061  0.789741  1.227585      0.163779
# 1        -0.819964      3.948809  0.789741 -0.761621      0.163779
# 2         1.107810     -0.241061  0.789741  1.227585      0.163779
# 3         1.107810     -0.241061 -1.026041 -0.761621      0.163779
# 4         1.107810     -0.241061  0.789741  1.227585      1.390023
# ...            ...           ...       ...       ...           ...
# 1455     -0.819964     -0.241061  0.789741  1.227585      0.163779
# 1456      1.107810     -0.241061  0.789741 -0.761621      0.163779
# 1457     -0.819964     -0.241061  0.789741 -0.761621      1.390023
# 1458      1.107810     -0.241061 -1.026041 -0.761621     -1.062465
# 1459      1.107810     -0.241061 -1.026041  1.227585      0.163779
#
#       Fireplaces  GarageArea PavedDrive
# 0      -0.951226    0.351000          Y
# 1       0.600495   -0.060731          Y
# 2       0.600495    0.631726          Y
# 3       0.600495    0.790804          Y
# 4       0.600495    1.698485          Y
# ...          ...         ...        ...
# 1455    0.600495   -0.060731          Y
# 1456    2.152216    0.126420          Y
# 1457    2.152216   -1.033914          Y
# 1458   -0.951226   -1.090059          Y
# 1459   -0.951226   -0.921624          Y
#
# [1460 rows x 20 columns]

# %% [markdown]
# ## Encoding Categorical Variables

# %%
# Check the number of categories for each categorical column
print("Unique Categories for each categorical columns\n")
for col in dataset.select_dtypes(include=['object']).columns.to_list():
    print(col, '\n--------------')
    print(dataset[col].unique(), '\n')
# Out:
# Unique Categories for each categorical columns
#
# MSZoning
# --------------
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
#
# Neighborhood
# --------------
# ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
#
# BldgType
# --------------
# ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
#
# HouseStyle
# --------------
# ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
#
# PavedDrive
# --------------
# ['Y' 'N' 'P']

# %%
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1,4,5,6,19])],remainder='passthrough')
X = ct.fit_transform(X)
X
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.16377912,
#         -0.95122649,  0.35100032],
#        [ 0.        ,  0.        ,  0.        , ...,  0.16377912,
#          0.60049493, -0.06073101],
#        [ 0.        ,  0.        ,  0.        , ...,  0.16377912,
#          0.60049493,  0.63172623],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  1.39002276,
#          2.15221636, -1.03391416],
#        [ 0.        ,  0.        ,  0.        , ..., -1.06246453,
#         -0.95122649, -1.09005935],
#        [ 0.        ,  0.        ,  0.        , ...,  0.16377912,
#         -0.95122649, -0.9216238 ]])

# %% [markdown]
# ## Splitting the dataset into training and testing datasets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Use sklearn Pipeline to preprocess and fit a model

# %%
from sklearn.preprocessing import FunctionTransformer
from copy import deepcopy

# Separate features from target
X = data.iloc[:,:-1]
y = data.iloc[:,-1].values

# Fix missing values using the median
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
imputer.fit(X.select_dtypes(include=['int', 'float']))
int_cols = X.select_dtypes(include=['float', 'int']).columns.to_list()
X[int_cols] = imputer.transform(X[int_cols])

# OneHot encode the categorical columns
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1,4,5,6,19])],remainder='passthrough')
X = ct.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Standardise the whole dataset
std_scaler = StandardScaler().fit(X_train)

def preprocessor(X):
    D = np.copy(X)
    D = std_scaler.transform(D)
    return D

# %%
preprocessor_transformer = FunctionTransformer(preprocessor)
preprocessor_transformer
# Out:
# FunctionTransformer(func=<function preprocessor at 0x0000024013C07C18>)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

p1 = Pipeline([('scaler', preprocessor_transformer),
              ('Linear Regression', LinearRegression())])
p1
# Out:
# Pipeline(steps=[('scaler',
#                  FunctionTransformer(func=<function preprocessor at 0x0000024013C07C18>)),
#                 ('Linear Regression', LinearRegression())])

# %%
from sklearn.metrics import mean_absolute_error

def fit_and_print(p, X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test):
    # Fit the transformer
    p.fit(X_train, y_train)
    # Predict the train and test outputs
    training_prediction = p.predict(X_train)
    test_prediction =p.predict(X_test)
    
    # Print the errors
    print("Training Error:     "+str(mean_absolute_error(training_prediction, y_train)))
    print("Test Error:         "+str(mean_absolute_error(test_prediction, y_test)))

# %%
fit_and_print(p1)
# Out:
# Training Error:     19509.44950784384
# Test Error:         19274.451575872787

# %% [markdown]
# ## Fit a KNN regressor

# %%
# Perform Grid search
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor as KNR

# Create a KNN Regressor
knn = KNR()

# Define Hyperparameters to tune
param_grid = {
    'n_neighbors': [3,5,7,9,11]
}

# Perform Grid Search
grid_search = GridSearchCV(estimator=knn, param_grid=param_grid,
                          scoring='neg_mean_squared_error', cv=5)
# Fit Grid Search to Data
grid_search.fit(X_train, y_train)
# Retrieve Best Parameters
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

# %%
print("best_params: ", best_params, "\nbest_estimator: ", best_estimator)
# Out:
# best_params:  {'n_neighbors': 5}
# best_estimator:  KNeighborsRegressor()

# %%
p2 = Pipeline([('Scaler', preprocessor_transformer),
               ('KNN Regression', KNR(n_neighbors=9))])
fit_and_print(p2)
# Out:
# Training Error:     23759.7824391172
# Test Error:         25870.157534246577

# %% [markdown]
# ## Fit a RandomForestRegressor()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
p3 = Pipeline([('Scaler', preprocessor_transformer),
               ('RFR Regression', RandomForestRegressor(max_depth=20, min_samples_split=5, n_estimators=150))])
fit_and_print(p3)
# Out:
# Training Error:     8465.699756573451
# Test Error:         19354.41295224088

# %% [markdown]
# ## Fit SVM Regression

# %%
from sklearn.svm import SVR
p4 = Pipeline([('Scaler', preprocessor_transformer),
               ('SVR Regression', SVR(kernel="rbf"))])
fit_and_print(p4)
# Out:
# Training Error:     56715.34150444794
# Test Error:         50750.34774694336

# %% [markdown]
# ## Fit a GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
p5 = Pipeline([('Scaler', preprocessor_transformer),
               ('GBR Regression', GradientBoostingRegressor())])
fit_and_print(p5)
# Out:
# Training Error:     12891.419604473238
# Test Error:         18812.591880031232

# %% [markdown]
# ## Fit an XGBoost Regressor

# %%
from xgboost import XGBRegressor

p5 = Pipeline([('Scaler', preprocessor_transformer),
               ('XGBR Regression', XGBRegressor())])
fit_and_print(p5)
# Out:
# Training Error:     1710.256103515625
# Test Error:         18636.495177386558

# %% [markdown]
# # Conclusion

# %% [markdown]
# * Most models performed well except SVM Regressor which was the worst
# * GradientBoostingRegressor was the best performing model overall

# %%
import numpy as np
arr = np.arange(y_test.max())

# %%
# Standardize the Data
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Fit GradientBoostingRegressor
gb_reg = GradientBoostingRegressor()
gb_reg.fit(X_train, y_train)
y_pred = gb_reg.predict(X_test)

# Visualize the performance in a scatter plot
plt.figure(figsize=(16, 8))
plt.scatter(y_test, y_pred)
plt.plot(arr, arr, c='brown')
plt.title("Actual VS Prediction", size=18)
plt.xlabel("Actual", size=14)
plt.ylabel("Prediction", size=14)
plt.show()

# %% [markdown]
# ### Fit an Artificial Neural Network Regression Model

# %%
std_scaler_y = StandardScaler().fit(y_train.reshape(-1, 1))
X_train = std_scaler.transform(X_train)
X_test = std_scaler.transform(X_test)

y_train = std_scaler_y.transform(y_train.reshape(-1, 1))
y_test = std_scaler_y.transform(y_test.reshape(-1, 1))

# %%
import tensorflow as tf
from tensorflow import keras
from functools import partial

RegularizedDense = partial(keras.layers.Dense,
                          activation='elu',
                          kernel_initializer='he_normal')
kernelregularizer = keras.regularizers.l2(0.01)

model = keras.models.Sequential([
    keras.layers.InputLayer(input_shape=X_train.shape[1:]),
    RegularizedDense(20),
    RegularizedDense(20),
    RegularizedDense(20),
    RegularizedDense(20),
    RegularizedDense(1)
])

model.compile(loss='mse', optimizer='adam')
# Fit the model
model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test),
         callbacks=[tf.keras.callbacks.EarlyStopping(patience=10)])
# Out:
# Epoch 1/100
# 37/37 [==============================] - 2s 8ms/step - loss: 1.9524 - val_loss: 1.5676
# Epoch 2/100
# 37/37 [==============================] - 0s 4ms/step - loss: 1.8584 - val_loss: 1.5621
# Epoch 3/100
# 37/37 [==============================] - 0s 4ms/step - loss: 1.8424 - val_loss: 1.5555
# Epoch 4/100
# 37/37 [==============================] - 0s 5ms/step - loss: 1.8366 - val_loss: 1.5251
# Epoch 5/100
# 37/37 [==============================] - 0s 4ms/step - loss: 1.8085 - val_loss: 1.4999
# Epoch 6/100
# 37/37 [==============================] - 0s 4ms/step - loss: 1.8603 - val_loss: 0.8513
# Epoch 7/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.8713 - val_loss: 0.5753
# Epoch 8/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.5592 - val_loss: 0.4605
# Epoch 9/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.4972 - val_loss: 0.4095
# Epoch 10/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.4369 - val_loss: 0.3791
# Epoch 11/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.4003 - val_loss: 0.3222
# Epoch 12/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.3669 - val_loss: 0.3182
# Epoch 13/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.3513 - val_loss: 0.3058
# Epoch 14/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.3374 - val_loss: 0.2759
# Epoch 15/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.3011 - val_loss: 0.2726
# Epoch 16/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.3111 - val_loss: 0.3302
# Epoch 17/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.3063 - val_loss: 0.2721
# Epoch 18/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.2783 - val_loss: 0.3530
# Epoch 19/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.3160 - val_loss: 0.2899
# Epoch 20/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.2933 - val_loss: 0.2715
# Epoch 21/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.2763 - val_loss: 0.2974
# Epoch 22/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.2659 - val_loss: 0.2814
# Epoch 23/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.2620 - val_loss: 0.2670
# Epoch 24/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.2540 - val_loss: 0.2961
# Epoch 25/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.2879 - val_loss: 0.4082
# Epoch 26/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.2864 - val_loss: 0.2623
# Epoch 27/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.2343 - val_loss: 0.2538
# Epoch 28/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.2390 - val_loss: 0.2634
# Epoch 29/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.2360 - val_loss: 0.2809
# Epoch 30/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.2282 - val_loss: 0.2761
# Epoch 31/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.2282 - val_loss: 0.2656
# Epoch 32/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.2287 - val_loss: 0.2656
# Epoch 33/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.2310 - val_loss: 0.2682
# Epoch 34/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.2217 - val_loss: 0.2612
# Epoch 35/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.2177 - val_loss: 0.2594
# Epoch 36/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.2097 - val_loss: 0.2713
# Epoch 37/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.2157 - val_loss: 0.2698

# %%
model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2698
# 0.269812673330307

# %%
y_pred.shape, y_test.shape
# Out:
# ((292, 1), (292, 1))

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# 10/10 [==============================] - 0s 2ms/step
# [[-0.14493042  0.09402119]
#  [ 0.20929703 -0.06153162]
#  [-0.59723938 -0.71485341]
#  [-0.89370733 -0.47841314]
#  [-0.65449548 -0.46721334]
#  [-0.68770134 -0.9027612 ]
#  [-0.9999969  -0.47841314]
#  [-0.54777759 -0.55307849]
#  [-0.3466652  -1.03218113]
#  [-0.32501775 -0.71485341]
#  [-0.66630882 -0.6588544 ]
#  [ 0.03283182  0.45751699]
#  [ 0.71116537  0.08157696]
#  [-0.71989328 -0.77707453]
#  [-0.74463701 -0.920432  ]
#  [ 0.65988511  0.70378819]
#  [-0.65786833 -0.52943446]
#  [-1.         -0.97618212]
#  [-0.82377332 -0.51574582]
#  [-0.76230681 -0.66507651]
#  [ 0.59353054  1.00786282]
#  [ 0.24610618 -0.1050864 ]
#  [-0.71252108 -0.49144224]
#  [-0.78896618 -0.83929565]
#  [-0.80115098 -0.82622922]
#  [-0.99999797  0.10646541]
#  [-0.79965949 -1.0471142 ]
#  [-0.74315166 -0.65263229]
#  [-0.70603639 -0.54063426]
#  [-0.02178413  0.03180007]
#  [-0.99999714  1.7739915 ]
#  [-0.62350714 -0.53441215]
#  [-0.92745447 -0.78951876]
#  [-0.9999947  -1.83096347]
#  [-0.63034499 -0.37885935]
#  [-0.9999783  -1.0135148 ]
#  [ 2.1417191   0.96511691]
#  [-0.26538676 -0.02419895]
#  [-0.92912656 -1.02595902]
#  [-0.31259561 -0.46596892]
#  [-0.68101776 -0.34774878]
#  [ 0.02107516  0.71623242]
#  [-0.80952281 -1.28728774]
#  [-0.6133498  -0.28552766]
#  [-0.9415887  -1.2188445 ]
#  [-0.80407178 -0.73351975]
#  [-0.99996471 -0.65387671]
#  [-0.66554165 -0.3539709 ]
#  [-0.99240625 -0.51574582]
#  [-0.67251182 -0.93262734]
#  [-0.79601395 -0.78951876]
#  [-0.65308571 -0.48774631]
#  [-0.63905686 -0.26686132]
#  [-0.81211799 -0.52819004]
#  [ 0.39818045 -0.22965309]
#  [ 0.24686316  0.84789231]
#  [-0.66422653 -0.49707948]
#  [ 0.30880949  0.2775735 ]
#  [-0.99834156 -0.34152667]
#  [-0.15764517 -0.05530951]
#  [ 0.95525879  1.71177038]
#  [ 0.20187119 -0.2768167 ]
#  [ 0.01439444  0.54201327]
#  [-0.79710126 -0.08019796]
#  [ 0.39024368  0.76600931]
#  [-0.89359772 -0.56552271]
#  [ 0.22860178  0.56690172]
#  [ 0.20937553 -0.21521779]
#  [-0.66451311 -0.54063426]
#  [-0.46083272 -0.06153162]
#  [ 2.33053231  2.60775455]
#  [-0.64109564 -0.3539709 ]
#  [ 0.83089346  0.57934595]
#  [-0.27817661 -0.32286033]
#  [ 0.31060973  1.2140014 ]
#  [ 0.39086643 -0.65263229]
#  [-0.63120258  0.05668851]
#  [-0.52164233 -0.62774384]
#  [ 0.94719809  3.01679621]
#  [-0.90057635 -0.52819004]
#  [-0.48454463 -0.34152667]
#  [-0.15079761 -0.1050864 ]
#  [-0.79987657 -0.5593006 ]
#  [-0.9999575  -1.26239929]
#  [-0.71276641 -1.0912912 ]
#  [-0.8940379  -1.3183983 ]
#  [ 0.1747947  -0.05530951]
#  [-0.14185649  0.03055564]
#  [ 0.52992982  0.84067466]
#  [ 0.39906707  0.09402119]
#  [-0.21943104 -0.37885935]
#  [ 0.04800591  2.61397666]
#  [ 2.00772166  3.76506743]
#  [-0.64671993 -0.83929565]
#  [-0.223216    0.0778437 ]
#  [-0.39985681  0.09402119]
#  [-0.47037339 -0.29174977]
#  [-0.5524348  -0.08642007]
#  [-0.74746728 -0.27930555]
#  [-0.85969639 -0.82685143]
#  [ 0.11883006  0.09402119]
#  [ 0.56017578  0.46734792]
#  [-0.99999708 -0.67752073]
#  [-0.7711032  -0.89529466]
#  [-0.88153732 -0.47841314]
#  [-0.26610851 -0.304194  ]
#  [-0.71263063 -0.18597386]
#  [-0.7150231  -0.57174483]
#  [ 0.22967729 -0.14241908]
#  [ 1.44949102  2.06020867]
#  [-0.75387293 -0.34152667]
#  [ 1.23550761  0.96511691]
#  [ 0.73235923  0.90165136]
#  [-0.85190582 -0.93262734]
#  [ 0.25206545  0.01935584]
#  [-0.47293508 -0.304194  ]
#  [-0.83290339 -0.66507651]
#  [ 0.62034792 -0.03042106]
#  [ 0.05590454  0.03180007]
#  [ 0.23427936  0.59179017]
#  [-0.71510601 -0.51574582]
#  [-0.55531663 -0.54063426]
#  [-0.66092139 -0.36641512]
#  [-0.74399132 -0.56552271]
#  [ 0.50796539  0.11890964]
#  [-0.37967998 -0.16730753]
#  [-0.29527891  0.65401129]
#  [-0.74589092 -1.05084747]
#  [-0.77488458 -0.37885935]]

# %%
# Visualize the performance in a scatter plot
plt.figure(figsize=(16, 8))
plt.scatter(y_test, y_pred)
plt.plot(np.arange(np.min(y_test),np.max(y_test)), np.arange(np.min(y_test),np.max(y_test)), c='brown')
plt.title("Actual VS Prediction", size=18)
plt.xlabel("Actual", size=14)
plt.ylabel("Prediction", size=14)
plt.show()
